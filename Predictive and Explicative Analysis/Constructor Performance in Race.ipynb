# %% [markdown]
# ## RaceResult Fact Analysis

# %% [markdown]
# #### Import

# %%
# %matplotlib inline
import psycopg2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pip
#import geopandas
import altair as alt
from descartes.patch import PolygonPatch
from datetime import datetime

# %% [markdown]
# ### Data  Extraction

# %% [markdown]
# #### Connection to database

# %%
def DbConnect():
    conn = psycopg2.connect(host="localhost",database="FormulaOne",port=5432,user='postgres',password='root')
    return conn

# %%
circuit = pd.read_sql('select * from "CircuitDim"', con=DbConnect())
races= pd.read_sql('select * from "RaceDim"', con=DbConnect())
date= pd.read_sql('select * from "DateTimeDim"', con=DbConnect())
races= pd.read_sql('select * from "RaceDim"', con=DbConnect())
driver= pd.read_sql('select * from "DriverDim"', con=DbConnect())
constructor= pd.read_sql('select * from "ConstructorsDim"', con=DbConnect())
status= pd.read_sql('select * from "StatusDim"', con=DbConnect())
result= pd.read_sql('select * from "RaceResultFact"', con=DbConnect())
# Out:
# C:\Anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# C:\Anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# C:\Anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# C:\Anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# C:\Anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# C:\Anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# C:\Anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# C:\Anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %% [markdown]
# ### Merging to a single DataFrame

# %% [markdown]
# ##### Renaming Keys

# %%
races.rename(columns = {'datetime_fk':'dateId'}, inplace = True)
races.rename(columns = {'circuit_fk':'CircuitId'}, inplace = True)
result.rename(columns = {'race_fk':'raceId'}, inplace = True)
result.rename(columns = {'driver_fk':'DriverID'}, inplace = True)
result.rename(columns = {'constructor_fk':'constructorId'}, inplace = True)
result.rename(columns = {'status_fk':'statusId'}, inplace = True)

# %%
df1 = pd.merge(races,date, on='dateId', how='inner')
Racedim = pd.merge(df1,circuit, on='CircuitId', how='inner')
df2 = pd.merge(result,Racedim, on='raceId', how='inner')
df3 = pd.merge(df2,driver, on='DriverID', how='inner')
df4 = pd.merge(df3,constructor, on='constructorId', how='inner')
df5 = pd.merge(df4,status, on='statusId', how='inner')

# %% [markdown]
# ### Data Anlysis

# %% [markdown]
# ##### Preparing

# %%
Fact=df5

# %%
Fact.columns
# Out:
# Index(['raceId', 'DriverID', 'constructorId', 'statusId', 'points_x', 'rank',
#        'laps', 'fastest_lapspeed', 'wins', 'laptime', 'pitstop', 'penalty_fk',
#        'round', 'name_x', 'CircuitId', 'dateId', 'weather_fk', 'date', 'day',
#        'month', 'year', 'time', 'circuitRef', 'name_y', 'location', 'latitude',
#        'longitude', 'Altitude', 'country', 'img', 'DriverRef', 'Number',
#        'Code', 'ForeName', 'SurName', 'Dob', 'Nationality', 'points_y', 'car',
#        'constructorRef', 'constructorName', 'constructorNationality',
#        'status'],
#       dtype='object')

# %% [markdown]
# ##### Cleaning

# %%
Fact["nameDriver"]=Fact["ForeName"]+" "+Fact["SurName"]
Fact["nameDriver"]
Fact['Dob']=pd.to_datetime(Fact['Dob'])
date=datetime.today()-Fact['Dob']
Fact['age']=round(date.dt.days/365)

# %% [markdown]
# Calculating the drivers' age is more significant that having a birth date as it provides us a mesurable value.

# %%
Fact.drop(columns=['raceId',
                   'DriverID',
                   'CircuitId',
                   'dateId',
                   'constructorRef',
                   'DriverRef',
                   'circuitRef',
                   'ForeName',
                   'SurName',
                   'Dob',
                   'Number',
                   'Code',
                    'day',
                   'month'],axis=1,inplace=True)

# %%
Fact.rename(columns = {'name_x':'nameGP','name_y':'nameCircuit'}, inplace = True)

# %%
Fact.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3543 entries, 0 to 3542
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   constructorId           3543 non-null   int64
#  1   statusId                3543 non-null   int64
#  2   points_x                3543 non-null   float64
#  3   rank                    3543 non-null   int64
#  4   laps                    3543 non-null   int64
#  5   fastest_lapspeed        3532 non-null   float64
#  6   wins                    3543 non-null   int64
#  7   laptime                 3543 non-null   object
#  8   pitstop                 3543 non-null   object
#  9   penalty_fk              2902 non-null   float64
#  10  round                   3543 non-null   int64
#  11  nameGP                  3543 non-null   object
#  12  weather_fk              3543 non-null   int64
#  13  date                    3543 non-null   object
#  14  year                    3543 non-null   int64
#  15  time                    3543 non-null   object
#  16  nameCircuit             3543 non-null   object
#  17  location                3543 non-null   object
#  18  latitude                3543 non-null   float64
#  19  longitude               3543 non-null   float64
#  20  Altitude                3543 non-null   int64
#  21  country                 3543 non-null   object
#  22  img                     3543 non-null   object
#  23  Nationality             3543 non-null   object
#  24  points_y                3538 non-null   float64
#  25  car                     3538 non-null   object
#  26  constructorName         3543 non-null   object
#  27  constructorNationality  3543 non-null   object
#  28  status                  3543 non-null   object
#  29  nameDriver              3543 non-null   object
#  30  age                     3543 non-null   float64
# dtypes: float64(7), int64(9), object(15)
# memory usage: 885.8+ KB

# %%
Fact.shape
# Out:
# (3543, 31)

# %%
Fact.head()
# Out:
#    constructorId  statusId  points_x  rank  laps  fastest_lapspeed  wins  \
# 0              9         1      25.0     1    56           196.523     1
# 1              9         1      18.0     2    56           193.677     0
# 2              9         1      25.0     1    58           213.669     1
# 3              9         1      25.0     1    66           192.262     1
# 4              9         1      25.0     1    78           157.656     1
#
#            laptime          pitstop  penalty_fk  ...   country  \
# 0  01:37:39.832000  00:01:07.225000        25.0  ...  Malaysia
# 1  01:37:03.424000  00:00:43.528000        25.0  ...     China
# 2  01:30:17.558000  00:01:21.609000        25.0  ...    Turkey
# 3  01:39:03.301000  00:01:20.858000        25.0  ...     Spain
# 4  02:09:38.373000  00:00:28.536000        25.0  ...    Monaco
#
#                                                  img  Nationality points_y  \
# 0  //upload.wikimedia.org/wikipedia/commons/thumb...       German     43.0
# 1  https://f1chronicle.com/wp-content/uploads/202...       German     43.0
# 2  https://f1chronicle.com/wp-content/uploads/202...       German     43.0
# 3  https://f1chronicle.com/wp-content/uploads/202...       German     43.0
# 4  https://f1chronicle.com/wp-content/uploads/202...       German     43.0
#
#                      car constructorName constructorNationality    status  \
# 0  Aston Martin Mercedes        Red Bull               Austrian  Finished
# 1  Aston Martin Mercedes        Red Bull               Austrian  Finished
# 2  Aston Martin Mercedes        Red Bull               Austrian  Finished
# 3  Aston Martin Mercedes        Red Bull               Austrian  Finished
# 4  Aston Martin Mercedes        Red Bull               Austrian  Finished
#
#          nameDriver   age
# 0  Sebastian Vettel  35.0
# 1  Sebastian Vettel  35.0
# 2  Sebastian Vettel  35.0
# 3  Sebastian Vettel  35.0
# 4  Sebastian Vettel  35.0
#
# [5 rows x 31 columns]

# %%
Fact.tail()
# Out:
#       constructorId  statusId  points_x  rank  laps  fastest_lapspeed  wins  \
# 3538            164       111       0.0    16    39           226.650     0
# 3539              5        79       0.0    16    47           196.298     0
# 3540              4       137       0.0    19    28           212.478     0
# 3541              4        60       0.0    18    53           201.487     0
# 3542            210       139       0.0    18    47           222.930     0
#
#               laptime          pitstop  penalty_fk  ...    country  \
# 3538  01:22:09.502000  00:17:15.495000        44.0  ...      Italy
# 3539  01:09:16.358000  00:00:50.933000       113.0  ...     Canada
# 3540  00:43:19.322000  00:00:33.027000        44.0  ...  Australia
# 3541  01:27:16.482000  00:00:25.676000        44.0  ...    Bahrain
# 3542  01:04:14.971000  00:00:30.708000       104.0  ...      Italy
#
#                                                     img  Nationality points_y  \
# 3538  https://f1chronicle.com/wp-content/uploads/202...   Australian    115.0
# 3539  https://www.automobile-magazine.fr/img/f1/circ...      Russian     32.0
# 3540  https://f1chronicle.com/wp-content/uploads/202...   Australian    115.0
# 3541  https://f1chronicle.com/wp-content/uploads/202...   Australian    115.0
# 3542  https://f1chronicle.com/wp-content/uploads/202...       Danish      1.0
#
#                    car constructorName constructorNationality       status  \
# 3538  McLaren Mercedes             HRT                Spanish     +14 Laps
# 3539  AlphaTauri Honda      Toro Rosso                Italian   Drivetrain
# 3540  McLaren Mercedes         Renault                 French       Damage
# 3541  McLaren Mercedes         Renault                 French  Out of fuel
# 3542      Haas Ferrari    Haas F1 Team               American      Illness
#
#             nameDriver   age
# 3538  Daniel Ricciardo  33.0
# 3539      Daniil Kvyat  28.0
# 3540  Daniel Ricciardo  33.0
# 3541  Daniel Ricciardo  33.0
# 3542   Kevin Magnussen  30.0
#
# [5 rows x 31 columns]

# %% [markdown]
# #####  Checking for null Data

# %%
Fact.isnull().sum()*100/len(Fact)
# Out:
# constructorId              0.000000
# statusId                   0.000000
# points_x                   0.000000
# rank                       0.000000
# laps                       0.000000
# fastest_lapspeed           0.310471
# wins                       0.000000
# laptime                    0.000000
# pitstop                    0.000000
# penalty_fk                18.092012
# round                      0.000000
# nameGP                     0.000000
# weather_fk                 0.000000
# date                       0.000000
# year                       0.000000
# time                       0.000000
# nameCircuit                0.000000
# location                   0.000000
# latitude                   0.000000
# longitude                  0.000000
# Altitude                   0.000000
# country                    0.000000
# img                        0.000000
# Nationality                0.000000
# points_y                   0.141123
# car                        0.141123
# constructorName            0.000000
# constructorNationality     0.000000
# status                     0.000000
# nameDriver                 0.000000
# age                        0.000000
# dtype: float64

# %% [markdown]
# ##### Analysis

# %% [markdown]
# Status

# %% [markdown]
# ## Car performance: merge weather

# %%
config=pd.read_csv("DE2-PI.csv",header=0,sep =',')
Factcar=pd.merge(Fact,config, on=["constructorId"], how='inner')
Factcar
# Out:
#       constructorId  statusId  points_x  rank  laps  fastest_lapspeed  wins  \
# 0                 9         1      25.0     1    56           196.523     1
# 1                 9         1      18.0     2    56           193.677     0
# 2                 9         1      25.0     1    58           213.669     1
# 3                 9         1      25.0     1    66           192.262     1
# 4                 9         1      25.0     1    78           157.656     1
# ...             ...       ...       ...   ...   ...               ...   ...
# 3538            164        13       0.0    20    68           194.759     0
# 3539            164        26       0.0    21    48           184.664     0
# 3540            164        14       0.0    18    66           177.456     0
# 3541            164        14       0.0    19    57           153.386     0
# 3542            164       111       0.0    16    39           226.650     0
#
#               laptime          pitstop  penalty_fk  ...      status  \
# 0     01:37:39.832000  00:01:07.225000        25.0  ...    Finished
# 1     01:37:03.424000  00:00:43.528000        25.0  ...    Finished
# 2     01:30:17.558000  00:01:21.609000        25.0  ...    Finished
# 3     01:39:03.301000  00:01:20.858000        25.0  ...    Finished
# 4     02:09:38.373000  00:00:28.536000        25.0  ...    Finished
# ...               ...              ...         ...  ...         ...
# 3538  01:33:27.563000  00:00:46.377000        44.0  ...     +3 Laps
# 3539  01:29:24.467000  00:00:44.885000        44.0  ...  Mechanical
# 3540  01:47:37.531000  00:01:08.058000        44.0  ...     +4 Laps
# 3541  01:59:46.220000  00:01:52.010000        44.0  ...     +4 Laps
# 3542  01:22:09.502000  00:17:15.495000        44.0  ...    +14 Laps
#
#             nameDriver   age constructorName_y  mpg displacement horsepower  \
# 0     Sebastian Vettel  35.0          red_bull   36           91        600
# 1     Sebastian Vettel  35.0          red_bull   36           91        600
# 2     Sebastian Vettel  35.0          red_bull   36           91        600
# 3     Sebastian Vettel  35.0          red_bull   36           91        600
# 4     Sebastian Vettel  35.0          red_bull   36           91        600
# ...                ...   ...               ...  ...          ...        ...
# 3538  Daniel Ricciardo  33.0               hrt   28          112        880
# 3539  Daniel Ricciardo  33.0               hrt   28          112        880
# 3540  Daniel Ricciardo  33.0               hrt   28          112        880
# 3541  Daniel Ricciardo  33.0               hrt   28          112        880
# 3542  Daniel Ricciardo  33.0               hrt   28          112        880
#
#      weight  acceleration  winingRate
# 0      1800           260           1
# 1      1800           260           1
# 2      1800           260           1
# 3      1800           260           1
# 4      1800           260           1
# ...     ...           ...         ...
# 3538   2605           268           1
# 3539   2605           268           1
# 3540   2605           268           1
# 3541   2605           268           1
# 3542   2605           268           1
#
# [3543 rows x 38 columns]

# %%
Factcar.rename(columns = {'constructorName_y':'constructorName'}, inplace = True)
Factcar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3543 entries, 0 to 3542
# Data columns (total 38 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   constructorId           3543 non-null   int64
#  1   statusId                3543 non-null   int64
#  2   points_x                3543 non-null   float64
#  3   rank                    3543 non-null   int64
#  4   laps                    3543 non-null   int64
#  5   fastest_lapspeed        3532 non-null   float64
#  6   wins                    3543 non-null   int64
#  7   laptime                 3543 non-null   object
#  8   pitstop                 3543 non-null   object
#  9   penalty_fk              2902 non-null   float64
#  10  round                   3543 non-null   int64
#  11  nameGP                  3543 non-null   object
#  12  weather_fk              3543 non-null   int64
#  13  date                    3543 non-null   object
#  14  year                    3543 non-null   int64
#  15  time                    3543 non-null   object
#  16  nameCircuit             3543 non-null   object
#  17  location                3543 non-null   object
#  18  latitude                3543 non-null   float64
#  19  longitude               3543 non-null   float64
#  20  Altitude                3543 non-null   int64
#  21  country                 3543 non-null   object
#  22  img                     3543 non-null   object
#  23  Nationality             3543 non-null   object
#  24  points_y                3538 non-null   float64
#  25  car                     3538 non-null   object
#  26  constructorName_x       3543 non-null   object
#  27  constructorNationality  3543 non-null   object
#  28  status                  3543 non-null   object
#  29  nameDriver              3543 non-null   object
#  30  age                     3543 non-null   float64
#  31  constructorName         3543 non-null   object
#  32  mpg                     3543 non-null   int64
#  33  displacement            3543 non-null   int64
#  34  horsepower              3543 non-null   int64
#  35  weight                  3543 non-null   int64
#  36  acceleration            3543 non-null   int64
#  37  winingRate              3543 non-null   int64
# dtypes: float64(7), int64(15), object(16)
# memory usage: 1.1+ MB

# %%
CarRS=Factcar.drop(columns=['nameGP',
                   'constructorNationality',
                   'img',
                    'statusId',
                   'points_x',
                   'points_x',
                    'Nationality',
                    'longitude',
                    'latitude',
                    'location',
                        'time',
                           'Altitude',
                           'date',
                            'country',
                            'age',
                            'penalty_fk',
                            'weather_fk',
                            'nameDriver',
                            'winingRate',
                            'displacement',
                            'laps',
                            'fastest_lapspeed',
                            'wins',
                            'laptime',
                            'pitstop',
                            'status',
                            'mpg',
                            'weight',
                            'round',
                            'car'
                           ])
#CarRS['pitstop']=CarRS['pitstop'].astype(str)
#CarRS['pitstop']=CarRS['pitstop'].replace(":", "", regex=True)
#CarRS['nameDriver']=CarRS['nameDriver'].replace(" ", "", regex=True)
#CarRS['pitstop']=CarRS['pitstop'].replace("None", "0", regex=True)

# %%
CarRS['points_y'] = CarRS['points_y'].fillna(0).astype(np.int64, errors='ignore')

CarRS.isnull().sum()*100/len(CarRS)
# Out:
# constructorId        0.0
# rank                 0.0
# year                 0.0
# nameCircuit          0.0
# points_y             0.0
# constructorName_x    0.0
# constructorName      0.0
# horsepower           0.0
# acceleration         0.0
# dtype: float64

# %%
CarRS['winning']=0
for i in range(0,len(CarRS)):
    pos=CarRS['rank'].iat[i]
    if pos>0 and pos<10:
         CarRS['winning'].iat[i] = int(1)
    else:
        
         CarRS['winning'].iat[i] = int(0)

# %%
CarRS.drop(columns=['rank'],axis=1,inplace=True)

# %%
df1=CarRS
df1=CarRS.groupby(["constructorId"]).sum('winning')

# %%
df1["performance"]=df1["winning"]/CarRS.groupby(["constructorId"]).size()

# %%
df=df1["performance"].to_frame()

df.to_csv(r'perfCons.csv')
df
# Out:
#                performance
# constructorId
# 1                 0.521053
# 3                 0.282857
# 4                 0.374302
# 5                 0.254237
# 6                 0.822454
# 9                 0.833846
# 10                0.584746
# 15                0.168385
# 51                0.144444
# 117               0.352941
# 131               0.894150
# 164               0.000000
# 206               0.015385
# 207               0.000000
# 208               0.530769
# 209               0.000000
# 210               0.170000
# 211               0.507042
# 213               0.468085
# 214               0.500000

# %%
constructor
# Out:
#      constructorId constructorRef constructorName constructorNationality
# 0                1        mclaren         McLaren                British
# 1                2     bmw_sauber      BMW Sauber                 German
# 2                3       williams        Williams                British
# 3                4        renault         Renault                 French
# 4                5     toro_rosso      Toro Rosso                Italian
# ..             ...            ...             ...                    ...
# 206            209          manor  Manor Marussia                British
# 207            210           haas    Haas F1 Team               American
# 208            211   racing_point    Racing Point                British
# 209            213     alphatauri      AlphaTauri                Italian
# 210            214         alpine  Alpine F1 Team                 French
#
# [211 rows x 4 columns]

# %%
df1 = pd.merge(df,constructor, on='constructorId', how='inner')
df2 = pd.merge(df1,config, on='constructorId', how='inner')

# %%
CarRS=df2
CarRS=CarRS.drop(columns=['constructorId','constructorRef','constructorName_y','mpg','displacement','winingRate'
                           ])
CarRS.rename(columns = {'constructorName_x':'constructorName'}, inplace = True)
CarRS.sort_values(by="performance",ascending=False).head(15)
CarRS.to_csv(r'perfCons.csv')

# %%
from sklearn.preprocessing import LabelEncoder
lb_make = LabelEncoder()
CarRS["constructorName"] = lb_make.fit_transform(CarRS["constructorName"])
CarRS["constructorNationality"] = lb_make.fit_transform(CarRS["constructorNationality"])
CarRS.sort_values(by="performance",ascending=False).head(15)
# Out:
#     performance  constructorName  constructorNationality  horsepower  weight  \
# 10     0.894150               13                       4         860    2395
# 5      0.833846               15                       1         600    1800
# 4      0.822454                5                       6         530    1795
# 6      0.584746                6                       5         710    1825
# 14     0.530769                9                       2         880    1890
# 0      0.521053               12                       2         690    1613
# 17     0.507042               14                       2         950    1904
# 19     0.500000                2                       3         650    1914
# 18     0.468085                1                       6         600    1910
# 2      0.374302               16                       3         600    1760
# 9      0.352941                3                       2         960    2300
# 1      0.282857               19                       2         580    1755
# 3      0.254237               18                       6         650    1773
# 16     0.170000                8                       0         600    1901
# 7      0.168385               17                      10         620    1845
#
#     acceleration
# 10           250
# 5            260
# 4            280
# 6            220
# 14           256
# 0            280
# 17           247
# 19           258
# 18           233
# 2            260
# 9            255
# 1            270
# 3            290
# 16           266
# 7            250

# %% [markdown]
# # Regression Linéaire multiple : Car Performance

# %% [markdown]
# ## $$f(X_1,X_2,...)= a_0 + a_1*X_1 + a_2*X_2 + .... + a_{12}*X12$$

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
X = CarRS.drop(['performance'], axis=1)
y = CarRS[['performance']]
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.2, random_state=0)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, median_absolute_error, r2_score
#Régression linéaire multiple (toutes les variables de Boston) 
regressor = LinearRegression()

#Fitting model with trainig data
regressor.fit(X, y)
y_pred = regressor.predict(X_test)

print('test_score = ',regressor.score(X_test,y_test)) 
print('R2 = ',r2_score(y_test, y_pred))
print('MAE = ',mean_squared_error(y_test, y_pred))
print('RMSE = ', np.sqrt(mean_squared_error(y_test, y_pred)))
print('MAE = ', mean_absolute_error(y_test, y_pred))
print('MeadianAE = ', median_absolute_error(y_test, y_pred))

print('Intercept = ', regressor.intercept_)
print('Coefficients : ',regressor.coef_)
# Out:
# test_score =  0.45990971979384454
# R2 =  0.45990971979384454
# MAE =  0.011233880715846774
# RMSE =  0.10599000290521166
# MAE =  0.0962177680468066
# MeadianAE =  0.07650012653641691
# Intercept =  [1.54523369]
# Coefficients :  [[ 1.04420479e-03 -3.08280285e-02  5.73550631e-05 -1.66952501e-04
#   -2.92124305e-03]]

# %%
import pickle

pickle.dump(regressor, open('ConstructorperformancePredictorInRace.pkl','wb'))

# Loading model to compare the results
model = pickle.load(open('ConstructorperformancePredictorInRace.pkl','rb'))
